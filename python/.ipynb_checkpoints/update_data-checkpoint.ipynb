# %%
# combine pieces with working database
import pandas as pd
import glob
import datetime
import matplotlib.pyplot as plt

path = r"./data/raw/pieces" # use your path
all_files = glob.glob(path + "/*.csv")

df_working = pd.read_csv(r'./data/raw\\lor_ranked_data_all.csv')
li = [df_working]

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
frame.head(5)
# Out:
#                                match_id  game_start_time_utc game_version  \
# 0  600109d3-3b69-489a-8244-d6f7c1e62837  2022-02-15 18:49:59  live_3_02_7
# 1  600109d3-3b69-489a-8244-d6f7c1e62837  2022-02-15 18:49:59  live_3_02_7
# 2  6b1424c3-3682-4f9d-82c1-ac579da49515  2022-02-15 20:12:31  live_3_02_7
# 3  6b1424c3-3682-4f9d-82c1-ac579da49515  2022-02-15 20:12:31  live_3_02_7
# 4  91b9f684-aac7-4a6e-8403-dda486ef3147  2022-02-15 20:06:40  live_3_02_7
#
#          player                                          deck_code  \
# 0      게임할개#KR1  CQCQCAYCAUAQIAQPAECQUOQCAUBAIFIFAEBAWDBMGEZAIA...
# 1  kuroge3#1113  CQBQGBIHA4FQ4BAFBIAQMSNGAECQIBZFEZEUYWICAECAOD...
# 2   sayy35#1622       CMBAKBAGAEBQKBYPBACAOAITCY3ECRCKKAAACAIEAYCA
# 3  Clarity#6393  CQAQQBIKAF2IIAMYAGTADLYBYIA4MAICAIAQCCBSAUCQUK...
# 4  Clarity#6393  CQAQQBIKAF2IIAMYAGTADLYBYIA4MAICAIAQCCBSAUCQUK...
#
#   game_outcome  order_of_play  total_turn_count   faction_1 faction_2  \
# ...

# %%
#check if you've missed any dates

fig, ax = plt.subplots()
frame['game_start_time_utc'].value_counts().plot(ax=ax, kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-279d75ad95de> in <module>
#       4
#       5 fig, ax = plt.subplots()
# ----> 6 frame['game_start_time_utc'].value_counts().plot(ax=ax, kind='bar')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
# thing = frame['game_start_time_utc'].to_datetime()
thing = pd.to_datetime(frame['game_start_time_utc'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-03852c4ed7fd> in <module>
#       1 # thing = frame['game_start_time_utc'].to_datetime()
# ----> 2 thing = pd.to_datetime(frame['game_start_time_utc'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     799                 result = result.tz_localize(tz)
#     800     elif isinstance(arg, ABCSeries):
# --> 801         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     802         if not cache_array.empty:
#     803             result = arg.map(cache_array)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     176         unique_dates = unique(arg)
# ...

# %%
thing = frame['game_start_time_utc'].str[:10]

# %%
x = thing.value_counts()

# %%
x.sort_index(ascending=True, inplace=True)
x
# Out:
# 2022-02-15     2176
# 2022-02-16    30324
# 2022-02-17    84892
# 2022-02-18    74226
# 2022-02-19    66986
# 2022-02-20    62558
# 2022-02-21    63728
# 2022-02-22    64176
# 2022-02-23    63091
# 2022-02-24    59304
# 2022-02-25    53284
# Name: game_start_time_utc, dtype: int64

# %%
fig, ax = plt.subplots()
x.plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
thing.value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
# fig, ax = plt.subplots()
# print(thing)
thing.value_counts()
# print(thing)
thing = thing.sort_values(ascending=False)
print(thing)
thing.plot(ax=ax, kind='bar')
# Out:
# 624744    2022-02-25
# 621881    2022-02-25
# 621146    2022-02-25
# 621158    2022-02-25
# 621157    2022-02-25
#              ...
# 523       2022-02-15
# 524       2022-02-15
# 525       2022-02-15
# 526       2022-02-15
# 0         2022-02-15
# Name: game_start_time_utc, Length: 624745, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-cb6116e6f19f> in <module>
#       5 thing = thing.sort_values(ascending=False)
#       6 print(thing)
# ----> 7 thing.plot(ax=ax, kind='bar')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ...
