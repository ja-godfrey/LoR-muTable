# %% [markdown]
# ## Put in a deck code to find out:
# - [ ] how how much is was played on each day
# - [ ] how many players have played it (and how much?)
# - [ ] what is its winrate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'./../data/raw/lor_ranked_data_all.csv')

# %%
deck = 'CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUAQCAYDBKHQDAIDBEGQ7AA'

# %%
df_x['archetype']
# Out:
# 2126065    Teemo Twisted Fate (BC)
# 2126359    Teemo Twisted Fate (BC)
# 2135094    Teemo Twisted Fate (BC)
# 2137023    Teemo Twisted Fate (BC)
# 2138196    Teemo Twisted Fate (BC)
#                     ...
# 2395224    Teemo Twisted Fate (BC)
# 2395624    Teemo Twisted Fate (BC)
# 2395671    Teemo Twisted Fate (BC)
# 2396730    Teemo Twisted Fate (BC)
# 2398074    Teemo Twisted Fate (BC)
# Name: archetype, Length: 253, dtype: object

# %%
df_x = df[df['deck_code'] == deck] # make dataframe of just the best deck
thing = pd.to_datetime(df_x['game_start_time_utc'].str[:10]) # just get the dates
dates = thing.value_counts() # how many games are played per day?
dates.sort_index(ascending=True, inplace=True) # sort the dates

fig, ax = plt.subplots(figsize=(2,2)) # graph to see if you're missing any dates
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# plt.title(f'Top Deck playrate over time \n{deck_wr0}% winrate yesterday')
plt.xlabel('Date')
plt.ylabel('Number of Games')
dates.plot(ax=ax, kind='line')
plt.savefig(f'deckPopularity.png', bbox_inches="tight", dpi=200, transparent=True)

# %%
len(df_x['player'].unique())
# Out:
# 31

# %%
df_x
# Out:
#          Unnamed: 0                              match_id  \
# 2126065     2126065  f991b7ba-0270-4233-864d-57bfab8f5d63
# 2126359     2126359  c03a7227-af49-45a3-8960-0cc0add57df9
# 2135094     2135094  108a7ec5-37ac-4519-b91a-25e145241461
# 2137023     2137023  6148e8ea-0390-43d0-884c-d21e77a3512c
# 2138196     2138196  936b5d5f-3090-40a4-92c2-ab927e5dbe72
# ...             ...                                   ...
# 2395224     2395224  3780ec29-eefb-4f64-83fd-0d5e288d2a6c
# 2395624     2395624  4631f801-ce9f-48de-81a2-1705d8e6e6a4
# 2395671     2395671  f98c947d-2173-4de0-bfc8-0fbf32e663a8
# 2396730     2396730  761832ad-bade-4f94-879b-cd19a3480e1d
# 2398074     2398074  f2c52499-6502-4840-911e-ccab5fa4a913
#
#          game_start_time_utc  game_version            player  \
# 2126065  2022-08-03 19:37:21  live_3_12_11   underl1ght#4304
# 2126359  2022-08-03 19:48:45  live_3_12_11   underl1ght#4304
# 2135094  2022-08-03 19:21:28  live_3_12_11   underl1ght#4304
# 2137023  2022-08-03 19:31:24  live_3_12_11   underl1ght#4304
# 2138196  2022-08-03 00:29:08  live_3_12_11   underl1ght#4304
# ...                      ...           ...               ...
# 2395224  2022-08-07 18:40:16  live_3_12_11          Mìzz#EUW
# 2395624  2022-08-07 16:10:31  live_3_12_11  Devilreject#1437
# 2395671  2022-08-07 22:31:42  live_3_12_11        Thorax#EUW
# 2396730  2022-08-07 19:12:13  live_3_12_11  Devilreject#1437
# 2398074  2022-08-07 16:19:21  live_3_12_11  Devilreject#1437
#
#                                                  deck_code game_outcome  \
# 2126065  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...         loss
# 2126359  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...          win
# 2135094  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...          win
# 2137023  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...          win
# 2138196  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...          win
# ...                                                    ...          ...
# 2395224  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...          win
# 2395624  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...         loss
# 2395671  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...         loss
# 2396730  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...         loss
# 2398074  CQCQCAIEBAAQKCVGAEAQMBRJAIBQMDQUAUBAMFBBFU3TUA...         loss
#
#          order_of_play  total_turn_count   faction_1   faction_2  \
# 2126065              0                21  BandleCity  Bilgewater
# 2126359              0                41  BandleCity  Bilgewater
# 2135094              0                 7  BandleCity  Bilgewater
# 2137023              0                22  BandleCity  Bilgewater
# 2138196              0                20  BandleCity  Bilgewater
# ...                ...               ...         ...         ...
# 2395224              0                39  BandleCity  Bilgewater
# 2395624              1                33  BandleCity  Bilgewater
# 2395671              1                28  BandleCity  Bilgewater
# 2396730              1                18  BandleCity  Bilgewater
# 2398074              1                17  BandleCity  Bilgewater
#
#                        archetype  is_master    region
# 2126065  Teemo Twisted Fate (BC)          0  americas
# 2126359  Teemo Twisted Fate (BC)          0  americas
# 2135094  Teemo Twisted Fate (BC)          0  americas
# 2137023  Teemo Twisted Fate (BC)          0  americas
# 2138196  Teemo Twisted Fate (BC)          0  americas
# ...                          ...        ...       ...
# 2395224  Teemo Twisted Fate (BC)          0    europe
# 2395624  Teemo Twisted Fate (BC)          0    europe
# 2395671  Teemo Twisted Fate (BC)          0    europe
# 2396730  Teemo Twisted Fate (BC)          0    europe
# 2398074  Teemo Twisted Fate (BC)          0    europe
#
# [253 rows x 14 columns]
