# %% [markdown]
# ## Put in a deck code to find out:
# - [ ] how how much is was played on each day
# - [ ] how many players have played it (and how much?)
# - [ ] what is its winrate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'./../data/raw/lor_ranked_data_all.csv')

# %%
deck = 'CECAEAQDAMCAGAIFE42TQAYDAUBQIBQFAEBQEDAPFA3QAAIBAYBQY'

# %%
df_x['archetype']
# Out:
# 208614     Elise Annie
# 208620     Elise Annie
# 209377     Elise Annie
# 209776     Elise Annie
# 210088     Elise Annie
#               ...
# 2313809     Elise (NX)
# 2313914     Elise (NX)
# 2314065     Elise (NX)
# 2314079     Elise (NX)
# 2314213     Elise (NX)
# Name: archetype, Length: 348, dtype: object

# %%
df_x = df[df['deck_code'] == deck] # make dataframe of just the best deck
thing = pd.to_datetime(df_x['game_start_time_utc'].str[:10]) # just get the dates
dates = thing.value_counts() # how many games are played per day?
dates.sort_index(ascending=True, inplace=True) # sort the dates

fig, ax = plt.subplots(figsize=(2,2)) # graph to see if you're missing any dates
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# plt.title(f'Top Deck playrate over time \n{deck_wr0}% winrate yesterday')
plt.xlabel('Date')
plt.ylabel('Number of Games')
dates.plot(ax=ax, kind='line')
plt.savefig(f'deckPopularity.png', bbox_inches="tight", dpi=200, transparent=True)

# %%
len(df_x['player'].unique())
# Out:
# 12

# %%
df_x
# Out:
#          Unnamed: 0                              match_id  \
# 208614       208614  4bcd2978-a239-4a15-8034-f16d6b1f9d50
# 208620       208620  4e563b31-a13d-4a9d-a486-c4b26c7d119a
# 209377       209377  d291486f-a2ab-4328-9eb4-82046984c42f
# 209776       209776  b55c11d1-ee98-4966-b72b-28bfd3845fbe
# 210088       210088  21cb69dd-a8a9-40e0-9af0-40dab775d7a4
# ...             ...                                   ...
# 2313809     2313809  13da9bdb-c5f0-43a8-8bec-c647e3079685
# 2313914     2313914  d32b9717-b20b-4999-aef6-f47337288fb6
# 2314065     2314065  7988b09c-9307-437c-b3f0-4d9d671c3ee8
# 2314079     2314079  d5e21058-daf3-4dac-9d4b-1e623febd347
# 2314213     2314213  8ff33840-0846-423b-a320-1f649a02c177
#
#          game_start_time_utc  game_version            player  \
# 208614   2022-07-02 23:18:02  live_3_10_12       ªnºmª#gamig
# 208620   2022-07-03 01:50:24  live_3_10_12       ªnºmª#gamig
# 209377   2022-07-03 02:05:08  live_3_10_12       ªnºmª#gamig
# 209776   2022-07-03 02:11:40  live_3_10_12       ªnºmª#gamig
# 210088   2022-07-03 02:15:25  live_3_10_12       ªnºmª#gamig
